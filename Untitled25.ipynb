# %% [markdown]
# <a href="https://colab.research.google.com/github/dasw05/eegnet-based-embedded-bci/blob/main/Untitled25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !conda install -c conda-forge opencv ffmpeg
# Out:
# /bin/bash: conda: command not found

# %%
# !git clone https://github.com/Kubasinska/MI-EEG-1D-CNN.git
# Out:
# Cloning into 'MI-EEG-1D-CNN'...
# remote: Enumerating objects: 4223, done.
# remote: Counting objects: 100% (436/436), done.
# remote: Compressing objects: 100% (161/161), done.
# remote: Total 4223 (delta 284), reused 407 (delta 265), pack-reused 3787
# Receiving objects: 100% (4223/4223), 1.00 GiB | 44.35 MiB/s, done.
# Resolving deltas: 100% (993/993), done.

# %%
! wget https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
! chmod +x Miniconda3-py37_4.8.2-Linux-x86_64.sh
! bash ./Miniconda3-py37_4.8.2-Linux-x86_64.sh -b -f -p /usr/local
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')
# Out:
# --2022-06-18 16:14:31--  https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.131.3, 104.16.130.3, 2606:4700::6810:8303, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.131.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85055499 (81M) [application/x-sh]
# Saving to: ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh’
#
# Miniconda3-py37_4.8 100%[===================>]  81.12M   126MB/s    in 0.6s
#
# 2022-06-18 16:14:31 (126 MB/s) - ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh’ saved [85055499/85055499]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - asn1crypto==1.3.0=py37_0
#     - ca-certificates==2020.1.1=0
#     - certifi==2019.11.28=py37_0
#     - cffi==1.14.0=py37h2e261b9_0
#     - chardet==3.0.4=py37_1003
# ...

# %%
# !conda env create -f /content/MI-EEG-1D-CNN/docs/environment.yml
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.2
#   latest version: 4.13.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ...
# wheel-0.37.0         | 33 KB     | : 100% 1.0/1 [00:00<00:00,  6.01it/s]
# pyparsing-2.4.7      | 59 KB     | : 100% 1.0/1 [00:00<00:00, 27.64it/s]
# libgomp-9.3.0        | 311 KB    | : 100% 1.0/1 [00:00<00:00,  7.72it/s]
# tornado-6.1          | 588 KB    | : 100% 1.0/1 [00:00<00:00,  6.52it/s]
# munkres-1.1.4        | 13 KB     | : 100% 1.0/1 [00:00<00:00,  8.20it/s]
# libffi-3.3           | 50 KB     | : 100% 1.0/1 [00:00<00:00,  8.60it/s]
# six-1.16.0           | 18 KB     | : 100% 1.0/1 [00:00<00:00,  8.60it/s]
# libgfortran-ng-7.5.0 | 22 KB     | : 100% 1.0/1 [00:00<00:00,  8.80it/s]
# cycler-0.10.0        | 14 KB     | : 100% 1.0/1 [00:00<00:00,  8.69it/s]
# numpy-1.19.2         | 22 KB     | : 100% 1.0/1 [00:00<00:00,  9.29it/s]
# ...

# %%
# !wget -r -N -c -np https://physionet.org/files/eegmmidb/1.0.0/
# Out:
# Streaming output truncated to the last 5000 lines.
# Length: 2064384 (2.0M) [application/octet-stream]
# Saving to: ‘physionet.org/files/eegmmidb/1.0.0/S092/S092R03.edf’
#
# physionet.org/files 100%[===================>]   1.97M  11.5MB/s    in 0.2s
#
# 2022-06-18 16:27:37 (11.5 MB/s) - ‘physionet.org/files/eegmmidb/1.0.0/S092/S092R03.edf’ saved [2064384/2064384]
#
# --2022-06-18 16:27:37--  https://physionet.org/files/eegmmidb/1.0.0/S092/S092R03.edf.event
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 566 [text/plain]
# Saving to: ‘physionet.org/files/eegmmidb/1.0.0/S092/S092R03.edf.event’
#
# physionet.org/files 100%[===================>]     566  --.-KB/s    in 0s
#
# 2022-06-18 16:27:37 (142 MB/s) - ‘physionet.org/files/eegmmidb/1.0.0/S092/S092R03.edf.event’ saved [566/566]
#
# --2022-06-18 16:27:37--  https://physionet.org/files/eegmmidb/1.0.0/S092/S092R04.edf
# Reusing existing connection to physionet.org:443.
# ...

# %%
# !which conda
# Out:
# /usr/local/bin/conda

# %%
import sys
print(sys.version)
# Out:
# 3.7.13 (default, Apr 24 2022, 01:04:09)
# [GCC 7.5.0]

# %%
# %%bash
# conda activate test36
#
# python
# import sys
# # maybe only need this the first time we run this notebook
# sys.path.append('/usr/local/lib/python3.6/site-packages')
#
# print("Python version")
# print(sys.version)
# Out:
# Python version
# 3.7.6 (default, Jan  8 2020, 19:59:22)
# [GCC 7.3.0]
# CommandNotFoundError: Your shell has not been properly configured to use 'conda activate'.
# To initialize your shell, run
#
#     $ conda init <SHELL_NAME>
#
# Currently supported shells are:
#   - bash
#   - fish
#   - tcsh
#   - xonsh
#   - zsh
#   - powershell
#
# See 'conda init --help' for more information and options.
#
# IMPORTANT: You may need to close and restart your shell after running 'conda init'.

# %%
# %%shell
# eval "$(conda shell.bash hook)" # copy conda command to shell
# conda activate eeg
# python --version
# Out:
# Python 3.8.3

# %%
# !conda info --envs
# Out:
# # conda environments:
# #
# base                  *  /usr/local
# eeg                      /usr/local/envs/eeg

# %%
# !conda info
# Out:
#      active environment : None
#        user config file : /root/.condarc
#  populated config files :
#           conda version : 4.8.2
#     conda-build version : not installed
#          python version : 3.7.6.final.0
#        virtual packages : __cuda=11.2
#                           __glibc=2.27
#        base environment : /usr/local  (writable)
#            channel URLs : https://repo.anaconda.com/pkgs/main/linux-64
#                           https://repo.anaconda.com/pkgs/main/noarch
#                           https://repo.anaconda.com/pkgs/r/linux-64
#                           https://repo.anaconda.com/pkgs/r/noarch
#           package cache : /usr/local/pkgs
#                           /root/.conda/pkgs
#        envs directories : /usr/local/envs
#                           /root/.conda/envs
#                platform : linux-64
#              user-agent : conda/4.8.2 requests/2.22.0 CPython/3.7.6 Linux/5.4.188+ ubuntu/18.04.5 glibc/2.27
#                 UID:GID : 0:0
# ...

# %%
# !ls -rlt  /usr/local/envs
# Out:
# total 4
# drwxr-xr-x 22 root root 4096 Jun 18 16:17 eeg

# %%
# !python /content/MI-EEG-1D-CNN/dataset_generator/generator.py
# Out:
# Streaming output truncated to the last 5000 lines.
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Extracting EDF parameters from /content/physionet.org/files/eegmmidb/1.0.0/S081/S081R08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Extracting EDF parameters from /content/physionet.org/files/eegmmidb/1.0.0/S081/S081R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Extracting EDF parameters from /content/physionet.org/files/eegmmidb/1.0.0/S081/S081R12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# ...

# %%
# !pip install tensorflow-gpu==2.3.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !python /content/MI-EEG-1D-CNN/models/train_b.py
# Out:
# 2022-06-18 18:19:11.370758: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2022-06-18 18:19:12.709392: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2022-06-18 18:19:12.724676: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-18 18:19:12.725297: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2022-06-18 18:19:12.725337: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
# !pip install imbalanced-learn==0.8.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 189 kB 7.9 MB/s
# ...

# %%
# !conda install -c conda-forge imbalanced-learn
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - imbalanced-learn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     imbalanced-learn-0.7.0     |             py_1          97 KB  conda-forge
#     joblib-1.1.0               |     pyhd8ed1ab_0         210 KB  conda-forge
#     scikit-learn-0.23.2        |   py37hddcf8d6_3         6.8 MB  conda-forge
#     scipy-1.5.3                |   py37h14a347d_0        19.1 MB  conda-forge
#     threadpoolctl-3.1.0        |     pyh8a188c0_0          18 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        26.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   imbalanced-learn   conda-forge/noarch::imbalanced-learn-0.7.0-py_1
# ...

# %%
from imblearn import under_sampling, over_sampling
from imblearn.over_sampling import SMOTE
